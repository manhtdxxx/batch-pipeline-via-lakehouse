# %%
import pandas as pd

# %%
df_events = pd.read_csv("../data/company_events.csv")
df_events.head()
# Out:
#          id                                        event_title  \
# 0  58604768        ACB - Niêm yết bổ sung 669.998.687 cổ phiếu
# 1     18149        ACB- Niêm yết bổ sung 498.821.183 cổ phiếu
# 2  40234158        ACB - Niêm yết bổ sung 582,607,554 cổ phiếu
# 3   9972801        ACB - Niêm yết bổ sung 675,487,019 cổ phiếu
# 4  23057391  ACB - Trả cổ tức Cả năm năm 2022 bằng tiền 100...
#
#                                      en__event_title public_date  issue_date  \
# 0           ACB- Lists additional 669,998,687 shares  2025-06-27  2025-06-26
# 1          ACB- Lists additional 498,821,183 shares   2020-09-30  2020-10-05
# 2           ACB- Lists additional 582,607,554 shares  2024-06-28  2024-06-27
# 3           ACB- Lists additional 675,487,019 shares  2022-07-12  2022-07-06
# 4  ACB - Pay cash dividend 2022 - Year at VND 100...  2023-05-25  2023-06-12
#
#                                           source_url event_list_code  ratio  \
# ...

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   402 non-null    int64
#  1   event_title          402 non-null    object
#  2   en__event_title      401 non-null    object
#  3   public_date          402 non-null    object
#  4   issue_date           402 non-null    object
#  5   source_url           402 non-null    object
#  6   event_list_code      402 non-null    object
#  7   ratio                401 non-null    float64
#  8   value                401 non-null    float64
#  9   record_date          402 non-null    object
#  10  exright_date         402 non-null    object
#  11  event_list_name      402 non-null    object
#  12  en__event_list_name  402 non-null    object
#  13  symbol               402 non-null    object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 44.1+ KB

# %%
df_events.en__event_list_name.value_counts()
# Out:
# en__event_list_name
# Additional Listing    194
# Cash Dividend         124
# Share Issue            83
# New listing             1
# Name: count, dtype: int64

# %%
df_events[df_events.en__event_list_name == 'Cash Dividend'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 4 to 394
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   124 non-null    int64
#  1   event_title          124 non-null    object
#  2   en__event_title      124 non-null    object
#  3   public_date          124 non-null    object
#  4   issue_date           124 non-null    object
#  5   source_url           124 non-null    object
#  6   event_list_code      124 non-null    object
#  7   ratio                124 non-null    float64
#  8   value                124 non-null    float64
#  9   record_date          124 non-null    object
#  10  exright_date         124 non-null    object
#  11  event_list_name      124 non-null    object
#  12  en__event_list_name  124 non-null    object
#  13  symbol               124 non-null    object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 14.5+ KB

# %%
df_events[df_events.en__event_list_name == 'Additional Listing'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194 entries, 0 to 401
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   194 non-null    int64
#  1   event_title          194 non-null    object
#  2   en__event_title      193 non-null    object
#  3   public_date          194 non-null    object
#  4   issue_date           194 non-null    object
#  5   source_url           194 non-null    object
#  6   event_list_code      194 non-null    object
#  7   ratio                193 non-null    float64
#  8   value                193 non-null    float64
#  9   record_date          194 non-null    object
#  10  exright_date         194 non-null    object
#  11  event_list_name      194 non-null    object
#  12  en__event_list_name  194 non-null    object
#  13  symbol               194 non-null    object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 22.7+ KB

# %%
df_news = pd.read_csv("../data/company_news.csv")
df_news.head(3)
# Out:
#         id                                         news_title  news_sub_title  \
# 0  8805929  ACB: Nghị quyết và Biên bản kiểm phiếu bằng hì...             NaN
# 1  8699409  ACB: Dự thảo Nghị quyết ĐHĐCĐ thành lập công t...             NaN
# 2  8699410         ACB: Phiếu lấy ý kiến cổ đông bằng văn bản             NaN
#
#    friendly_sub_title                                     news_image_url  \
# 0                 NaN  https://cdn.fiingroup.vn/medialib/127889/I/202...
# 1                 NaN  https://cdn.fiingroup.vn/medialib/127889/I/202...
# 2                 NaN  https://cdn.fiingroup.vn/medialib/127889/I/202...
#
#                                     news_source_link  created_at public_date  \
# 0  https://www.hsx.vn/vi/tin-tuc/acb-nghi-quyet-v...         NaN  2025-11-11
# 1  https://www.hsx.vn/vi/tin-tuc/acb-du-thao-nghi...         NaN  2025-10-27
# 2  https://www.hsx.vn/vi/tin-tuc/acb-phieu-lay-y-...         NaN  2025-10-27
#
#    updated_at lang_code   news_id  \
# ...

# %%
df_news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  300 non-null    int64
#  1   news_title          300 non-null    object
#  2   news_sub_title      0 non-null      float64
#  3   friendly_sub_title  0 non-null      float64
#  4   news_image_url      293 non-null    object
#  5   news_source_link    299 non-null    object
#  6   created_at          0 non-null      float64
#  7   public_date         300 non-null    object
#  8   updated_at          0 non-null      float64
#  9   lang_code           300 non-null    object
#  10  news_id             300 non-null    int64
#  11  news_short_content  146 non-null    object
#  12  news_full_content   300 non-null    object
#  13  close_price         293 non-null    float64
#  14  ref_price           293 non-null    float64
# ...

# %%
df_news[df_news['floor'].isnull()]
# Out:
#           id                                         news_title  \
# 51   8665608  FPT báo lợi nhuận 6.800 tỷ đồng trong quý 3, t...
# 86   8729508  HDBank (HDB): Lợi nhuận 9 tháng vượt 14.800 tỷ...
# 116  8693345  MB đạt lợi nhuận trước thuế hơn 23.000 tỷ đồng...
# 128  8303158  MSN: Đính chính Báo cáo tình hình quản trị 6 t...
# 136  8649913  MWG lên kế hoạch mua lại 10 triệu cổ phiếu quỹ...
# 161  8729507  SHB sẽ chào bán riêng lẻ, phát hành cổ phiếu c...
# 166  8556880  SHB lấy ý kiến cổ đông bằng văn bản về phương ...
#
#      news_sub_title  friendly_sub_title  \
# 51              NaN                 NaN
# 86              NaN                 NaN
# 116             NaN                 NaN
# 128             NaN                 NaN
# 136             NaN                 NaN
# 161             NaN                 NaN
# 166             NaN                 NaN
#
#                                         news_image_url  \
# 51   https://cdn.fiingroup.vn/medialib/127379/I/202...
# ...

# %%
df_officers = pd.read_csv("../data/company_officers.csv")
df_officers.head()
# Out:
#    id       officer_name                officer_position position_short_name  \
# 0   6      Trần Hùng Huy      Chủ tịch Hội đồng Quản trị       Chủ tịch HĐQT
# 1   7      Đặng Thu Thủy    Thành viên Hội đồng Quản trị             TV HĐQT
# 2  17      Đặng Phú Vinh                   Giám đốc khối             GĐ Khối
# 3   8       Đỗ Minh Toàn                   Tổng Giám đốc                 TGĐ
# 4   9  Nguyễn Thành Long  Phó Chủ tịch Hội đồng Quản trị   Phó Chủ tịch HĐQT
#
#   update_date  officer_own_percent   quantity symbol
# 0  2025-08-12               0.0343  176021482    ACB
# 1  2025-08-12               0.0119   61352541    ACB
# 2  2025-08-12               0.0037   18922683    ACB
# 3  2025-08-12               0.0007    3683318    ACB
# 4  2025-08-12               0.0004    1894127    ACB

# %%
df_shareholders = pd.read_csv("../data/company_shareholders.csv")
df_shareholders.head()
# Out:
#          id                            share_holder   quantity  \
# 0  92382089  Vietnam Enterprise Investments Limited  212880184
# 1  92376898         Sather Gate Investments Limited  193907186
# 2  92358150               Estes Investments Limited   83010435
# 3  92374659                         Phạm Thị Thu Hà     285000
# 4  92357726       Dragon Financial Holdings Limited  140770684
#
#    share_own_percent update_date symbol
# 0           0.054809  2024-09-13    ACB
# 1           0.049900  2025-10-05    ACB
# 2           0.049900  2024-05-15    ACB
# 3           0.049900  2016-05-20    ACB
# 4           0.036243  2025-10-05    ACB
